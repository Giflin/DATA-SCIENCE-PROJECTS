# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Forbes.csv")

# %%
df.head()
# Out:
#    S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0     1         Mike Tyson         USA             1                NaN
# 1     2     Buster Douglas         USA             2                NaN
# 2     3  Sugar Ray Leonard         USA             3                NaN
# 3     4       Ayrton Senna      Brazil             4                NaN
# 4     5        Alain Prost      France             5                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# 3  auto racing  1990                  10.0
# 4  auto racing  1990                   9.0

# %%
df.iloc[4]
# Out:
# S.NO                              5
# Name                    Alain Prost
# Nationality                  France
# Current Rank                      5
# Previous Year Rank              NaN
# Sport                   auto racing
# Year                           1990
# earnings ($ million)            9.0
# Name: 4, dtype: object

# %%
df=df.set_index("Name")

# %%
df
# Out:
#                    S.NO Nationality  Current Rank Previous Year Rank  \
# Name
# Mike Tyson            1         USA             1                NaN
# Buster Douglas        2         USA             2                NaN
# Sugar Ray Leonard     3         USA             3                NaN
# Ayrton Senna          4      Brazil             4                NaN
# Alain Prost           5      France             5                NaN
# ...                 ...         ...           ...                ...
# Stephen Curry       297         USA             6                  9
# Kevin Durant        298         USA             7                 10
# Tiger Woods         299         USA             8                 11
# Kirk Cousins        300         USA             9               >100
# Carson Wentz        301         USA            10               >100
#
#                                Sport  Year  earnings ($ million)  \
# Name
# ...

# %%
df.loc["Kirk Cousins"]
# Out:
# S.NO                                  300
# Nationality                           USA
# Current Rank                            9
# Previous Year Rank                   >100
# Sport                   American Football
# Year                                 2020
# earnings ($ million)                 60.5
# 0                            Kirk Cousins
# Name: Kirk Cousins, dtype: object

# %%
df.dtypes
# Out:
# S.NO                      int64
# Nationality              object
# Current Rank              int64
# Previous Year Rank       object
# Sport                    object
# Year                      int64
# earnings ($ million)    float64
# 0                        object
# dtype: object

# %%
df[df["earnings ($ million)"]>100].sort_values(by="earnings ($ million)",ascending=False)[0:5]
# Out:
#                   S.NO  Nationality  Current Rank Previous Year Rank   Sport  \
# Name
# Floyd Mayweather   242          USA             1                  1  Boxing
# Floyd Mayweather   272          USA             1               >100  Boxing
# Manny Pacquiao     243  Philippines             2                 11  Boxing
# Lionel Messi       282    Argentina             1                  2  Soccer
# Tiger Woods        172          USA             1                  1    golf
#
#                   Year  earnings ($ million)                 0
# Name
# Floyd Mayweather  2015                 300.0  Floyd Mayweather
# Floyd Mayweather  2018                 285.0  Floyd Mayweather
# Manny Pacquiao    2015                 160.0    Manny Pacquiao
# Lionel Messi      2019                 127.0      Lionel Messi
# Tiger Woods       2008                 115.0       Tiger Woods

# %%
def simple(num):
    return int(num)

# %%
df["earnings ($ million)"].apply(simple)
# Out:
# Name
# Mike Tyson           28
# Buster Douglas       26
# Sugar Ray Leonard    13
# Ayrton Senna         10
# Alain Prost           9
#                      ..
# Stephen Curry        74
# Kevin Durant         63
# Tiger Woods          62
# Kirk Cousins         60
# Carson Wentz         59
# Name: earnings ($ million), Length: 301, dtype: int64

# %%
df[0]
# Out:
# Name
# Mike Tyson                  Mike Tyson
# Buster Douglas          Buster Douglas
# Sugar Ray Leonard    Sugar Ray Leonard
# Ayrton Senna              Ayrton Senna
# Alain Prost                Alain Prost
#                            ...
# Stephen Curry            Stephen Curry
# Kevin Durant              Kevin Durant
# Tiger Woods                Tiger Woods
# Kirk Cousins              Kirk Cousins
# Carson Wentz              Carson Wentz
# Name: 0, Length: 301, dtype: object

# %%
def first(name):
    return name.split(" ")[0]

# %%
df["First"]=df[0].apply(first)

# %%
df
# Out:
#                    S.NO Nationality  Current Rank Previous Year Rank  \
# Name
# Mike Tyson            1         USA             1                NaN
# Buster Douglas        2         USA             2                NaN
# Sugar Ray Leonard     3         USA             3                NaN
# Ayrton Senna          4      Brazil             4                NaN
# Alain Prost           5      France             5                NaN
# ...                 ...         ...           ...                ...
# Stephen Curry       297         USA             6                  9
# Kevin Durant        298         USA             7                 10
# Tiger Woods         299         USA             8                 11
# Kirk Cousins        300         USA             9               >100
# Carson Wentz        301         USA            10               >100
#
#                                Sport  Year  earnings ($ million)  \
# Name
# ...

# %%
def last(name):
    return name.split(" ")[1]

# %%
df["Last"]=df[0].apply(first)

# %%
df
# Out:
#                    S.NO Nationality  Current Rank Previous Year Rank  \
# Name
# Mike Tyson            1         USA             1                NaN
# Buster Douglas        2         USA             2                NaN
# Sugar Ray Leonard     3         USA             3                NaN
# Ayrton Senna          4      Brazil             4                NaN
# Alain Prost           5      France             5                NaN
# ...                 ...         ...           ...                ...
# Stephen Curry       297         USA             6                  9
# Kevin Durant        298         USA             7                 10
# Tiger Woods         299         USA             8                 11
# Kirk Cousins        300         USA             9               >100
# Carson Wentz        301         USA            10               >100
#
#                                Sport  Year  earnings ($ million)  \
# Name
# ...
